# %% [markdown]
# # Gross profit = Revenue - COGS

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
rev_m = 170 # expected mean revenue
rev_stdev = 20 #expected standard deviation
iterations = 100000 # number of iterations

# %% [markdown]
# **simulation of expected revenues**

# %%
rev = np.random.normal(rev_m,rev_stdev, iterations)
plt.plot(rev,'o')
plt.axhline(y = rev_m, color = 'r', linestyle = '-')

# %% [markdown]
# **Estimating COGS**

# %%
a = np.random.normal(0.6,0.1)
COGS = (rev * 0.6)
plt.plot(COGS,'o')
plt.axhline(y = COGS.mean(), color = 'r', linestyle = '-')

# %%
Gross_Profit = rev - COGS
plt.hist(Gross_Profit, bins = 20)
plt.ylabel('Gross Profit (Million$)')
# Out:
# Text(0, 0.5, 'Gross Profit (Million$)')

# %%
COGS.mean()
# Out:
# 102.04711646364439

# %%
COGS.std()
# Out:
# 11.999873268160842
