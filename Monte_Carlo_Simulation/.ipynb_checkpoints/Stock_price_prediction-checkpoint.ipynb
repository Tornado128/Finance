# %% [markdown]
# $$
#     price_{today} = price_{yesterday}  e^{(u-1/2 \sigma^2)+\sigma[rnd(0:1)]}
# $$

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import yfinance as yfin
from scipy.stats import norm
from pandas_datareader import data as pdr
# Out:
# C:\Users\yaser\anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
tickers = ['^GSPC']
yfin.pdr_override() #  you ensure compatibility with the Yahoo Finance API changes and possibly improve the reliability and functionality of data retrieval from Yahoo Finance within your code
data = pd.DataFrame()
for t in tickers:
    data[t] = pdr.get_data_yahoo(t, start="1961-3-30", end="2024-3-30")['Adj Close']
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %% [markdown]
# **log daily return**

# %%
log_return = np.log(data/data.shift(1))
log_return.head()
# Out:
#                ^GSPC
# Date
# 1961-03-30       NaN
# 1961-04-03  0.008266
# 1961-04-04  0.000914
# 1961-04-05 -0.003051
# 1961-04-06  0.002289

# %%
log_return[np.isnan(log_return)] = 0
log_return.head()
# Out:
#                ^GSPC
# Date
# 1961-03-30  0.000000
# 1961-04-03  0.008266
# 1961-04-04  0.000914
# 1961-04-05 -0.003051
# 1961-04-06  0.002289

# %%
plt.plot(log_return)

# %%
## mean
u = log_return.mean()
u
# Out:
# ^GSPC    0.000277
# dtype: float64

# %%
## variance
var = log_return.var()
var
# Out:
# ^GSPC    0.000108
# dtype: float64

# %%
## standard deviation
stdev = log_return.std()
stdev
# Out:
# ^GSPC    0.01038
# dtype: float64

# %% [markdown]
# **drift = u - 1/2 var**

# %%
drift = u - 1/2 * var
drift
# Out:
# ^GSPC    0.000223
# dtype: float64

# %%
# z value at a given probability
norm.ppf(0.95)
# Out:
# 1.6448536269514722

# %% [markdown]
# **Example to see Z value (multi-dimensional)**

# %%
# creating a matrix of 10 by 2 random values
x = np.random.rand(10,2)
x
# Out:
# array([[0.38780597, 0.06335654],
#        [0.59327109, 0.48536469],
#        [0.42155744, 0.14104751],
#        [0.56828573, 0.14524172],
#        [0.48653577, 0.18898132],
#        [0.58154973, 0.55551609],
#        [0.77778458, 0.18674567],
#        [0.14626782, 0.56307457],
#        [0.77616515, 0.67793496],
#        [0.84435885, 0.84687323]])

# %%
# z values corresponding to the random numbers that we created above
Z = norm.ppf(x)
Z
# Out:
# array([[-0.28504204, -1.52719281],
#        [ 0.2359676 , -0.03669352],
#        [-0.19791077, -1.07562496],
#        [ 0.17201142, -1.05706168],
#        [-0.03375622, -0.88165643],
#        [ 0.20585965,  0.1396104 ],
#        [ 0.76473252, -0.88995261],
#        [-1.05257539,  0.15876902],
#        [ 0.75930572,  0.46193202],
#        [ 1.01253506,  1.02311484]])

# %%
t_intervals = 1000 # forcast the price for the upcoming 1000 days 
iterations = 10 # 10 future stock predictions

# %% [markdown]
# $$
#     returns_{daily} = e^r; r = drift + volatility
# $$

# %%
daily_returns = np.exp(drift.values + stdev.values * norm.ppf(np.random.rand(t_intervals, iterations)))
daily_returns
# Out:
# array([[0.99678396, 0.98948732, 1.03085643, ..., 0.99851985, 1.00529586,
#         0.9997971 ],
#        [0.98826633, 0.99505115, 1.00912139, ..., 0.9985141 , 0.98174681,
#         1.00242222],
#        [1.003414  , 1.00907532, 0.99617141, ..., 0.99823431, 1.03020923,
#         0.99992879],
#        ...,
#        [0.99334334, 0.99386245, 0.99944762, ..., 0.98814049, 1.00045297,
#         1.00729206],
#        [0.98965321, 1.01027631, 0.99809841, ..., 1.02128283, 0.97781647,
#         1.002885  ],
#        [0.99942638, 0.99443041, 1.00243196, ..., 1.00591898, 1.0012072 ,
#         0.98462848]])

# %%
# today price (which is the last price available)
price_today = data.iloc[-1]

# %%
# create a price materix of zero for t_interval by iterations
price = np.zeros((t_intervals, iterations))
# today price
price [0] = price_today

# %%
for t in range(1,t_intervals):
    price [t] = price [t-1] * daily_returns[t]

# %%
plt.plot(price)
plt.show()
